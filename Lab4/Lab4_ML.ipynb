# %% [markdown]
# # 🧠 Machine Learning - Lab 4
# ## Linear Regression & Its Variants
#
# ---
#
# **Name:** Afnan Kamel
# **Course:** CS4082 - Machine Learning
# **Institution:** Effat University, Computer Science Department
# **Instructor:** Dr. Naila Marir
#
#
# ---

# %% [markdown]
# # Introduction

# %% [markdown]
# In this lab, we explored linear regression and its variants to predict continuous values using the California Housing dataset. The objective was to understand how different regression models operate and how accurately they can predict house prices based on features such as median income, geographic location, and population characteristics. The analysis began with simple linear regression using a single feature and then expanded to multiple linear regression using all available features to improve prediction accuracy. Polynomial regression was also applied to capture potential non-linear relationships between variables. In addition, regularization techniques including Ridge, Lasso, and ElasticNet were used to control model complexity and reduce the risk of overfitting. Finally, the performance of all models was evaluated and compared using regression metrics such as RMSE and R² to determine which model provided the most accurate predictions.

# %% [markdown]
# #  Part 2: Loading a Real Dataset – California Housing

# %% [markdown]
# ## Step 1: Load and Explore

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing

# Load the dataset
housing = fetch_california_housing()
df = pd.DataFrame(housing.data, columns = housing.feature_names)
df["MedHouseVal "] = housing.target # target in $100,000s

print (f"Dataset shape: {df. shape}")
print (f"\nFeature names:\n{housing.feature_names}")
print (f"\nFirst 5 rows:")
print (df.head())
print (f"\nBasic statistics:")
print (df.describe().round(3))
# Out:
# Dataset shape: (20640, 9)
#
# Feature names:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
#
# First 5 rows:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23         4.526
# 1    -122.22         3.585
# 2    -122.24         3.521
# 3    -122.25         3.413
# 4    -122.25         3.422
#
# Basic statistics:
#           MedInc   HouseAge   AveRooms  AveBedrms  Population   AveOccup  \
# count  20640.000  20640.000  20640.000  20640.000   20640.000  20640.000
# ...

# %% [markdown]
# ## Step 3: Visualize Relationships

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 10))
features_to_plot = ["MedInc", "HouseAge", "AveRooms",
                    "Population", "Latitude", "Longitude"]

for ax, feat in zip(axes.flatten(), features_to_plot):
  ax.scatter(df[feat], df["MedHouseVal "],
               alpha=0.1, s=5, color="steelblue")
  ax.set_xlabel(feat)
  ax.set_ylabel("MedHouseVal($100k)")
  ax.set_title(f"{feat} vs House Value")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 1: Explore the Dataset

# %% [markdown]
# 1. Use df.corr()[’MedHouseVal’].sort
# values() to rank features by their corre
# lation with the target. Which feature has the strongest correlation?

# %%
corr_with_target = df.corr()["MedHouseVal "].sort_values(ascending=False)
print(corr_with_target)

strongest_feature = corr_with_target.index[1]  # index[0] is 'MedHouseVal' itself
strongest_value = corr_with_target.iloc[1]
print(f"\nStrongest correlation with MedHouseVal: {strongest_feature} = {strongest_value:.3f}")
# Out:
# MedHouseVal     1.000000
# MedInc          0.688075
# AveRooms        0.151948
# HouseAge        0.105623
# AveOccup       -0.023737
# Population     -0.024650
# Longitude      -0.045967
# AveBedrms      -0.046701
# Latitude       -0.144160
# Name: MedHouseVal , dtype: float64
#
# Strongest correlation with MedHouseVal: MedInc = 0.688

# %% [markdown]
# The feature with the strongest correlation with MedHouseVal is MedInc, with a correlation value of 0.688. This indicates a strong positive relationship between median income and house value. Districts with higher median income tend to have higher house prices.

# %% [markdown]
# 2. Plot the distribution of MedHouseVal using plt.hist(df[’MedHouseVal’],
# bins=50). Is the target normally distributed? Do you notice any cap at $5.0
# (i.e., $500,000)?

# %%
plt.hist(df["MedHouseVal "], bins=50)
plt.title("Distribution of MedHouseVal")
plt.xlabel("MedHouseVal ($100,000s)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The distribution of MedHouseVal is not normally distributed. It is slightly right-skewed, meaning most house values are in the lower to middle range while fewer districts have very high values. There is also a clear cap at 5.0 ($500,000), which appears as a spike at the maximum value because prices in the dataset were limited at that value.

# %% [markdown]
# 3. How many samples are in the dataset? Is this enough for training a good model?

# %% [markdown]
# The dataset contains 20,640 samples, which is a large number of observations. This is sufficient for training a reliable machine learning model because larger datasets help the model learn patterns better and improve generalization.

# %% [markdown]
# # Part 3: Simple Linear Regression (One Feature)

# %% [markdown]
# ##  Step 1: Prepare Data

# %%
from sklearn.model_selection import train_test_split

# Use only MedInc as the feature
X_simple = df[["MedInc"]].values
y = df["MedHouseVal "].values

# Split : 80% train , 20% test
X_train, X_test, y_train, y_test = train_test_split(
    X_simple, y, test_size=0.2, random_state=42)

print(f"Training samples: {X_train.shape[0]}")
print(f"Testing samples: {X_test.shape[0]}")
# Out:
# Training samples: 16512
# Testing samples: 4128

# %% [markdown]
# ## Step 2: Train and Visualize

# %%
from sklearn.linear_model import LinearRegression

# Train
model_simple = LinearRegression()
model_simple.fit(X_train , y_train)

# Print the learned parameters
print(f"Slope(w1): {model_simple.coef_[0]:.4f}")
print(f"Intercept(w0): {model_simple.intercept_:.4f}")
print(f"\nEquation: y = {model_simple.coef_[0]:.4f} * MedInc + {model_simple.intercept_:.4f}")

# Visualize: scatter + regression line
plt.figure(figsize=(10 , 6))
plt.scatter(X_test, y_test, alpha=0.2, s=10,
            color="steelblue", label ="Actual")

# Draw the regression line
x_line = np.linspace(X_test.min(), X_test.max(), 100)
y_line = model_simple.predict(x_line.reshape(-1, 1))
plt.plot(x_line, y_line, color="red", linewidth=2,
         label="Regression Line")

plt.xlabel("Median Income($10,000s)")
plt.ylabel("Median House Value($100,000s)")
plt.title("Simple Linear Regression : Income vs House Value")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Slope(w1): 0.4193
# Intercept(w0): 0.4446
#
# Equation: y = 0.4193 * MedInc + 0.4446

# %% [markdown]
# ###Task 2: Interpret the Simple Model

# %% [markdown]
# 1. What are the slope and intercept your model learned? Write the equation.

# %% [markdown]
# The model learned a slope of 0.4179 and an intercept of 0.4502.
#
# Regression equation:
# y = 0.4179 * MedInc + 0.4502
#
# The slope (0.4179) means that for every increase of 1 unit in MedInc (which equals 10,000 in median income), the predicted house value increases by about 0.4179 in MedHouseVal units (around 41,790).
#
# The intercept (0.4502) represents the predicted house value when the median income is 0. Although this situation is not realistic, the intercept is necessary to define the regression line mathematically.

# %% [markdown]
# 2. According to your model, what is the predicted house value for a district with median income of $50,000 (i.e., MedInc = 5.0)? Calculate by hand and verify with model simple.predict([[5.0]]).

# %% [markdown]
# The regression equation is:
#
# y = 0.4179 * MedInc + 0.4502
#
# To predict the house value when MedInc = 5.0:
#
# y = 0.4179 * 5.0 + 0.4502
# y = 2.5397

# %%
model_simple.predict([[5.0]])
# Out:
# array([2.54128976])

# %% [markdown]
# 3. Try training a simple model using HouseAge instead of MedInc. Is it better or
# worse? Why?

# %%
# Train simple model using HouseAge instead of MedInc
X_age = df[["HouseAge"]].values
y = df["MedHouseVal "].values

X_train_age, X_test_age, y_train_age, y_test_age = train_test_split(
    X_age, y, test_size=0.2, random_state=42
)

model_age = LinearRegression()
model_age.fit(X_train_age, y_train_age)

# Print slope and intercept
print("Slope (w1):", model_age.coef_[0])
print("Intercept (w0):", model_age.intercept_)

# Predict
y_pred_age = model_age.predict(X_test_age)

# Evaluate with R²
from sklearn.metrics import r2_score
print("R² score:", r2_score(y_test_age, y_pred_age))
# Out:
# Slope (w1): 0.00951461867149602
# Intercept (w0): 1.7997500158647475
# R² score: 0.012551235533311389

# %% [markdown]
# The model using HouseAge performs worse than the model using MedInc. This is because HouseAge has a much lower correlation with MedHouseVal (about 0.1056), while MedInc has a much stronger correlation (about 0.6881). The slope for HouseAge (0.0095) is also very small, meaning house value changes very little as house age increases. In addition, the scatter plot shows widely scattered points and an almost flat regression line, indicating a weak relationship. Therefore, HouseAge is a poor predictor of house value compared to MedInc.

# %% [markdown]
# # Part 4: Evaluating Regression Models

# %% [markdown]
# ## Step 1: Evaluate the Simple Model

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predictions
y_pred_simple = model_simple.predict(X_test)

# Calculate metrics
mse = mean_squared_error(y_test, y_pred_simple)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred_simple)
r2 = r2_score(y_test, y_pred_simple)

print("=== Simple Linear Regression(MedInc only) ===")
print(f"MSE:{mse:.4f}")
print(f"RMSE:{rmse:.4f} (error in $100,000s)")
print(f"MAE:{mae:.4f} (error in $100,000s)")
print(f"R^2:{r2:.4f} ({r2 *100:.1f}% variance explained)")
# Out:
# === Simple Linear Regression(MedInc only) ===
# MSE:0.7091
# RMSE:0.8421 (error in $100,000s)
# MAE:0.6299 (error in $100,000s)
# R^2:0.4589 (45.9% variance explained)

# %% [markdown]
# ## Step 2: Visualize Predictions vs. Actual

# %%
fig, axes = plt.subplots(1, 2, figsize =(14, 5))

# Plot 1: Predicted vs Actual
axes[0].scatter(y_test, y_pred_simple, alpha=0.2, s=10,
                color ="steelblue")
axes[0].plot([0, 5], [0, 5], "r--", linewidth=2,
             label ="Perfect Prediction")
axes[0].set_xlabel("Actual House Value($100k)")
axes[0].set_ylabel("Predicted House Value($100k)")
axes[0].set_title("Predicted vs Actual")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Plot 2: Residuals(errors)
residuals = y_test - y_pred_simple
axes[1].scatter(y_pred_simple, residuals, alpha=0.2, s=10,
                color="coral")
axes[1].axhline(y=0, color="black", linewidth=1)
axes[1].set_xlabel("Predicted Value")
axes[1].set_ylabel("Residual(Actual - Predicted)")
axes[1].set_title("Residual Plot")
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 3: Understand the Metrics

# %% [markdown]
# 1. Convert the RMSE to actual dollars. If RMSE ≈ 0.74, what is the average prediction error in dollars?

# %% [markdown]
# The RMSE is 0.74, and the target variable MedHouseVal is measured in units of 100,000 dollars. To convert the RMSE to actual dollars:
#
# 0.74 × 100,000 = 74,000
#
# Therefore, the average prediction error of the model is approximately 74,000 dollars.

# %% [markdown]
# 2. Look at the “Predicted vs Actual” plot. Where does the model struggle most – at low values, high values, or both?

# %% [markdown]
# The model struggles most at high house values. The target variable is right-skewed and capped at 5.0 (500,000), which causes many high values to be compressed at this limit. As a result, the model tends to underpredict expensive houses, and the points in the Predicted vs Actual plot scatter away from the perfect prediction line (y = x) in the upper range.

# %% [markdown]
# 3. What does the R2 value tell you? Is a single feature enough to predict house prices well?

# %% [markdown]
# The R² value (about 0.48) indicates that the model explains about 48% of the variance in house values using only the MedInc feature. This shows that median income is an important predictor but not sufficient by itself. Housing prices depend on multiple factors such as location (latitude and longitude) and other district characteristics. Therefore, using a single feature is not enough for strong predictions, and a multiple regression model with all features would likely improve performance.

# %% [markdown]
# # Part 5: Multiple Linear Regression (All Features)

# %% [markdown]
# ##  Step 1: Train with All Features

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Use all features
X_all=df.drop(columns=["MedHouseVal "]).values
y=df["MedHouseVal "].values

# Split
X_train, X_test, y_train, y_test = train_test_split(
    X_all, y, test_size=0.2, random_state=42)

# Build pipeline with scaling(good practice!)
pipe_lr = Pipeline([
    ("scaler", StandardScaler()),
     ("lr", LinearRegression())
])

pipe_lr.fit(X_train, y_train)
y_pred_multi = pipe_lr.predict(X_test)

# Evaluate
r2_multi = r2_score(y_test, y_pred_multi)
rmse_multi = np.sqrt(mean_squared_error(y_test , y_pred_multi))

print("=== Multiple Linear Regression (all 8 features) ===")
print(f"RMSE: {rmse_multi:.4f}")
print(f"R^2: {r2_multi:.4f} ({r2_multi *100:.1f}% variance explained)")
print(f"\nImprovement over simple model:")
print(f"R^2: {r2 :.4f} -> { r2_multi :.4f} "f"(+{( r2_multi - r2) *100:.1f}%) ")
# Out:
# === Multiple Linear Regression (all 8 features) ===
# RMSE: 0.7456
# R^2: 0.5758 (57.6% variance explained)
#
# Improvement over simple model:
# R^2: 0.4589 -> 0.5758 (+11.7%)

# %% [markdown]
# ## Step 2: Feature Importance – Which Features Matter Most?

# %%
# Extract the learned coefficients
lr_model = pipe_lr.named_steps["lr"]
feature_names = housing.feature_names

# Since we scaled, coefficients are comparable
coef_df = pd.DataFrame({
    "Feature": feature_names,
    "Coefficient": lr_model.coef_
}) .sort_values("Coefficient", key=abs, ascending=False)

print("Feature Importance(by | coefficient |):")
print(coef_df.to_string(index = False))

# Visualize
plt.figure(figsize=(10, 5))
colors = ["steelblue" if c > 0 else "coral"
          for c in coef_df["Coefficient"]]
plt.barh(coef_df["Feature"], coef_df["Coefficient"], color = colors)
plt.xlabel("Coefficient Value(after scaling)")
plt.title ("Feature Importance in Multiple Linear Regression")
plt.axvline(x=0, color="black", linewidth=0.5)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# Feature Importance(by | coefficient |):
#    Feature  Coefficient
#   Latitude    -0.896929
#  Longitude    -0.869842
#     MedInc     0.854383
#  AveBedrms     0.339259
#   AveRooms    -0.294410
#   HouseAge     0.122546
#   AveOccup    -0.040829
# Population    -0.002308

# %% [markdown]
# ### Task 4: Analyze Multiple Regression

# %% [markdown]
# 1. List the top 3 most important features and the bottom 3. Does this make intuitive sense?

# %% [markdown]
# The top 3 most important features based on the absolute value of the coefficients are typically MedInc, Latitude, and Longitude, as they have the largest impact on predicting house values. The bottom 3 features are AveBedrms, Population, and HouseAge, since their coefficients are relatively small and contribute less to the prediction.
#
# This makes intuitive sense because median income strongly affects housing prices, and location (latitude and longitude) captures geographic effects such as proximity to the coast and major cities in California. In contrast, features like bedrooms, population, and house age have smaller or more indirect effects on house prices.

# %% [markdown]
# 2. Why does Latitude have a negative coefficient? What does this mean geographically for California?

# %% [markdown]
# Latitude has a negative coefficient because as latitude increases (moving north in California), the predicted house value tends to decrease. This means that homes located further north are generally less expensive compared to those in the southern or coastal regions. Geographically, this reflects the fact that many of the most expensive housing markets in California are located in coastal and southern areas, such as around Los Angeles and parts of the Bay Area, where demand and economic activity are higher.

# %% [markdown]
# 3. Create the “Predicted vs Actual” plot for the multiple regression model. Compare it visually with the simple model. Is it closer to the diagonal?

# %%
# Predicted vs Actual plot for Multiple Linear Regression

plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred_multi, alpha=0.2, s=10, color='steelblue')

# Perfect prediction line
plt.plot([0,5], [0,5], 'r--', linewidth=2)

plt.xlabel("Actual House Value ($100k)")
plt.ylabel("Predicted House Value ($100k)")
plt.title("Predicted vs Actual: Multiple Linear Regression")

plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# The multiple regression plot is closer to the diagonal line compared to the simple model. This means the predictions are more accurate and closer to the actual values. The points are less scattered around the diagonal, indicating that the multiple regression model performs better because it uses all available features instead of only one.

# %% [markdown]
# # Part 6: Polynomial Regression

# %% [markdown]
# ##  Step 1: Polynomial on a Single Feature

# %%
from sklearn.preprocessing import PolynomialFeatures

# Use only MedInc
X_simple = df[["MedInc"]].values
X_train_s, X_test_s, y_train, y_test = train_test_split(
    X_simple, y, test_size=0.2, random_state=42)

# Try degrees 1, 2, and 3
results = {}
plt.figure(figsize=(15, 4))
for i, degree in enumerate([1, 2, 3]):
  pipe_poly = Pipeline([
      ("poly", PolynomialFeatures(degree = degree,
                                  include_bias = False)),
      ("lr", LinearRegression())
  ])
  pipe_poly.fit(X_train_s, y_train)
  y_pred = pipe_poly.predict(X_test_s)

  r2_val = r2_score(y_test, y_pred)
  rmse_val = np.sqrt(mean_squared_error(y_test, y_pred))
  results[degree] = {"R2":r2_val, "RMSE":rmse_val}

  # Plot
  ax = plt.subplot(1, 3, i + 1)
  ax.scatter(X_test_s, y_test, alpha=0.1, s=5,
             color ="steelblue")

  x_plot = np.linspace(X_test_s.min(), X_test_s.max(),
                          300) .reshape(-1, 1)
  y_plot = pipe_poly.predict(x_plot)
  ax.plot(x_plot, y_plot, color="red", linewidth=2)
  ax.set_title(f"Degree {degree} (R$ ^2$={r2_val:.3f})")
  ax.set_xlabel("MedInc")
  ax.set_ylabel("MedHouseVal ")

plt.tight_layout()
plt.show()

# Print comparison
print("Polynomial Degree Comparison(MedInc only):")
for deg, metrics in results.items():
  print(f"Degree {deg}: R^2={metrics["R2"]:.4f}, "
f"RMSE ={metrics["RMSE"]:.4f}")
# Out:
# Polynomial Degree Comparison(MedInc only):
# Degree 1: R^2=0.4589, RMSE =0.8421
# Degree 2: R^2=0.4633, RMSE =0.8386
# Degree 3: R^2=0.4671, RMSE =0.8356

# %% [markdown]
# ## Step 2: Polynomial on All Features

# %%
from sklearn.preprocessing import StandardScaler

# Use all features with degree 2
X_train, X_test, y_train, y_test = train_test_split(
    X_all, y, test_size=0.2, random_state=42)
pipe_poly_all = Pipeline([
    ("scaler", StandardScaler()),
    ("poly", PolynomialFeatures(degree=2, include_bias=False)),
    ("lr", LinearRegression())
])

pipe_poly_all.fit(X_train, y_train)
y_pred_poly = pipe_poly_all.predict(X_test)

r2_poly = r2_score(y_test, y_pred_poly)
rmse_poly = np.sqrt(mean_squared_error(y_test, y_pred_poly))

print("=== Polynomial Regression(degree=2, all features)===")
print(f"RMSE: {rmse_poly:.4f}")
print(f"R^2: {r2_poly:.4f} ({r2_poly *100:.1f}% variance explained)")

# How many features now?
poly_features = pipe_poly_all.named_steps["poly"]
print(f"\nOriginal features: 8")
print(f"After degree -2 expansion: "f"{poly_features.n_output_features_}")
# Out:
# === Polynomial Regression(degree=2, all features)===
# RMSE: 0.6814
# R^2: 0.6457 (64.6% variance explained)
#
# Original features: 8
# After degree -2 expansion: 44

# %% [markdown]
# ### Task 5: Explore Polynomial Regression

# %% [markdown]
# 1. Look at the three plots for degrees 1, 2, and 3. Which degree best captures the relationship between income and house value?

# %% [markdown]
# Degree 3 best captures the relationship between income and house value. It has the highest R² (0.4671) and the lowest RMSE (0.8356) compared to degrees 1 and 2. The curve also follows the pattern of the data more closely, indicating that the degree 3 polynomial models the nonlinear relationship between median income and house value more effectively.

# %% [markdown]
# 2. Try degree 5 on the single-feature model. Does R2 keep improving, or does it start to behave strangely at the edges? This is overfitting!

# %%
# Degree 5 Polynomial Regression

pipe_poly5 = Pipeline([
    ('poly', PolynomialFeatures(degree=5, include_bias=False)),
    ('lr', LinearRegression())
])

pipe_poly5.fit(X_train_s, y_train)

# Predictions
y_pred5 = pipe_poly5.predict(X_test_s)

# Metrics
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

r2_5 = r2_score(y_test, y_pred5)
rmse_5 = np.sqrt(mean_squared_error(y_test, y_pred5))

print(f"Degree 5: R² = {r2_5:.4f}, RMSE = {rmse_5:.4f}")

# Plot
plt.figure(figsize=(6,4))
plt.scatter(X_test_s, y_test, alpha=0.1, s=5, color='steelblue')

x_plot = np.linspace(X_test_s.min(), X_test_s.max(), 300).reshape(-1,1)
y_plot = pipe_poly5.predict(x_plot)

plt.plot(x_plot, y_plot, color='red', linewidth=2)
plt.title(f"Degree 5 (R² = {r2_5:.3f})")
plt.xlabel("MedInc")
plt.ylabel("MedHouseVal")

plt.show()
# Out:
# Degree 5: R² = 0.4668, RMSE = 0.8359

# %% [markdown]
# R² does not continue to improve. It slightly decreases from 0.4671 (degree 3) to 0.4668 (degree 5), and the curve begins to behave strangely at the edges, bending unrealistically at higher income values. This indicates overfitting, where the model becomes too complex and starts fitting noise rather than the true relationship in the data.

# %% [markdown]
#  3. How many features does degree 3 create from 8 original features? Use PolynomialFeatures(degree=3).fit transform(X train).shape to check.

# %%
poly3 = PolynomialFeatures(degree=3)
X_poly3 = poly3.fit_transform(X_train)

print(X_poly3.shape)
# Out:
# (16512, 165)

# %% [markdown]
# Polynomial expansion with degree 3 and 8 original features creates 164 features (excluding the bias term). If the bias column is included, the total becomes 165 features. This demonstrates how polynomial features rapidly increase the dimensionality of the dataset.

# %% [markdown]
# # Part 7: Regularized Regression – Ridge, Lasso, and ElasticNet

# %% [markdown]
# ## Step 1: Train All Three Variants

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_all, y, test_size=0.2, random_state=42)

# Define models with pipelines
models = {
    "LinearRegression": Pipeline([
        ("scaler", StandardScaler()),
        ("model", LinearRegression())
    ]),
    "Ridge(alpha=1.0)": Pipeline([
        ("scaler", StandardScaler()),
        ("model", Ridge(alpha=1.0, random_state=42))
    ]),
    "Lasso(alpha=0.01)": Pipeline([
        ("scaler", StandardScaler()),
        ("model", Lasso(alpha=0.01, random_state=42))
    ]),
    "ElasticNet(alpha=0.01)": Pipeline([
        ("scaler", StandardScaler()),
        ("model", ElasticNet(alpha=0.01, l1_ratio=0.5,
                             random_state=42))
    ]),
}

# Train and evaluate each model
print(f"{"Model":<28} {"RMSE":>8} {"MAE":>8} {"R^2":>8}")
print("-" * 56)

results_dict = {}

for name, pipe in models.items():
  pipe.fit(X_train, y_train)
  y_pred = pipe.predict(X_test)
  rmse_val = np.sqrt(mean_squared_error(y_test, y_pred))
  mae_val = mean_absolute_error(y_test, y_pred)
  r2_val = r2_score(y_test, y_pred)

  results_dict[name] = {
      "RMSE": rmse_val, "MAE": mae_val, "R2": r2_val}
  print(f"{name:<28} {rmse_val:>8.4f} {mae_val:>8.4f}"
        f"{r2_val:>8.4f}")
# Out:
# Model                            RMSE      MAE      R^2
# --------------------------------------------------------
# LinearRegression               0.7456   0.5332  0.5758
# Ridge(alpha=1.0)               0.7456   0.5332  0.5758
# Lasso(alpha=0.01)              0.7404   0.5353  0.5816
# ElasticNet(alpha=0.01)         0.7416   0.5341  0.5803

# %% [markdown]
# ## Step 2: Compare Coefficients

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 5))
model_names = ["Ridge(alpha=1.0)",
               "Lasso(alpha=0.01)",
               "ElasticNet(alpha=0.01)"]
colors_list = ["steelblue", "coral", "seagreen"]

for ax, name, clr in zip(axes, model_names, colors_list):
  coefs = models[name].named_steps["model"].coef_
  ax.barh(housing.feature_names, coefs, color=clr)
  ax.set_title(name)
  ax.axvline(x=0, color="black", linewidth=0.5)
  ax.set_xlabel("Coefficient")

plt.tight_layout()
plt.show()

# Check which features Lasso set to zero
lasso_coefs = models ["Lasso(alpha=0.01)"].named_steps["model"].coef_
print ("\nLasso coefficients:")
for feat, coef in zip(housing.feature_names, lasso_coefs):
  status = "" if abs (coef) > 0.001 else " <-- REMOVED "
print(f"{feat:12s}:{coef:>8.4f}{ status}")
# Out:
# Lasso coefficients:
# Longitude   : -0.7557

# %% [markdown]
# ### Task 6: Explore Regularization

# %% [markdown]
# 1. Try different α values for Ridge: 0.01, 0.1, 1.0, 10.0, 100.0. Plot R2 vs α. What happens with very large α?

# %%
from sklearn.linear_model import Ridge
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

alphas = [0.01, 0.1, 1.0, 10.0, 100.0]
r2_scores = []


for alpha in alphas:
    model = Pipeline([
        ('scaler', StandardScaler()),
        ('ridge', Ridge(alpha=alpha))
    ])

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    r2 = r2_score(y_test, y_pred)
    r2_scores.append(r2)

    print(f"alpha = {alpha}, R² = {r2:.4f}")

# Plot
plt.figure(figsize=(6,4))
plt.plot(alphas, r2_scores, marker='o')
plt.xscale('log')
plt.xlabel("Alpha")
plt.ylabel("R² Score")
plt.title("Ridge Regression: R² vs Alpha")
plt.grid(True)
plt.show()
# Out:
# alpha = 0.01, R² = 0.5758
# alpha = 0.1, R² = 0.5758
# alpha = 1.0, R² = 0.5758
# alpha = 10.0, R² = 0.5761
# alpha = 100.0, R² = 0.5778

# %% [markdown]
# As α increases, the R² value changes only slightly and may improve a little within this range, indicating that Ridge regularization helps stabilize the model and reduce overfitting. However, if α becomes very large, the coefficients shrink too much toward zero, making the model overly simple. This leads to underfitting and a decrease in model performance.

# %% [markdown]
# 2. For Lasso, try alpha=0.1. How many features are removed (coefficient = 0)? Which ones?

# %%
lasso = Pipeline([
    ('scaler', StandardScaler()),
    ('model', Lasso(alpha=0.1, random_state=42))
])

lasso.fit(X_train, y_train)

coefs = lasso.named_steps['model'].coef_

removed = []

print("Lasso (alpha=0.1) coefficients:\n")

for feat, coef in zip(housing.feature_names, coefs):
    if abs(coef) < 0.0001:
        print(f"{feat:10s} : {coef: .4f} <-- REMOVED")
        removed.append(feat)
    else:
        print(f"{feat:10s} : {coef: .4f}")

print(f"\nTotal removed: {len(removed)}")
print(f"Removed features: {removed}")
# Out:
# Lasso (alpha=0.1) coefficients:
#
# MedInc     :  0.7106
# HouseAge   :  0.1065
# AveRooms   : -0.0000 <-- REMOVED
# AveBedrms  :  0.0000 <-- REMOVED
# Population : -0.0000 <-- REMOVED
# AveOccup   : -0.0000 <-- REMOVED
# Latitude   : -0.0115
# Longitude  : -0.0000 <-- REMOVED
#
# Total removed: 5
# Removed features: ['AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Longitude']

# %% [markdown]
# With alpha = 0.1, Lasso removes 5 features by setting their coefficients to zero. The removed features are AveRooms, AveBedrms, Population, AveOccup, and Longitude. This occurs because stronger regularization forces the model to shrink less important coefficients to zero, effectively performing feature selection and keeping only the most relevant predictors.

# %% [markdown]
#  3. In the ElasticNet, change l1 ratio from 0.0 to 1.0. At l1 ratio=0.0, what model does it become? At l1 ratio=1.0?

# %% [markdown]
# At l1_ratio = 0.0, ElasticNet becomes Ridge Regression because it uses only L2 regularization.
#
# At l1_ratio = 1.0, ElasticNet becomes Lasso Regression because it uses only L1 regularization.

# %% [markdown]
# # Part 8: The Alpha Tuning Experiment

# %% [markdown]
# ## Step 1: Ridge Alpha Search

# %%
alphas = [0.001, 0.01, 0.1, 0.5, 1.0, 5.0, 10.0,
          50.0, 100.0, 500.0]

train_scores = []
test_scores = []

for alpha in alphas:
  pipe = Pipeline([
      ("scaler", StandardScaler()),
      ("ridge", Ridge(alpha=alpha))
  ])
  pipe.fit(X_train, y_train)
  train_scores.append(r2_score(y_train,
                                pipe.predict(X_train)))
  test_scores.append(r2_score(y_test,
                                pipe.predict(X_test)))

# Plot
plt.figure(figsize=(10, 5))
plt.semilogx(alphas, train_scores, "o-",
             label="Train R^2", color="steelblue")
plt.semilogx(alphas, test_scores, "s-",
             label="Test R^2", color="coral")
plt.xlabel("Alpha(log scale)")
plt.ylabel("R^2 Score")
plt.title("Ridge Regression: Effect of Alpha")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# Best alpha
best_idx = np.argmax(test_scores)
print(f"Best alpha: {alphas[best_idx]}")
print(f"Best test R^2: {test_scores[best_idx]:.4f}")
# Out:
# Best alpha: 100.0
# Best test R^2: 0.5778

# %% [markdown]
# ### Task 7: Tune Lasso Alpha

# %% [markdown]
# 1. Repeat the alpha search experiment for Lasso using alphas: [0.0001, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1.0].

# %%
from sklearn.linear_model import Lasso
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import numpy as np

alphas = [0.0001, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1.0]

train_scores = []
test_scores = []
features_kept = []

for alpha in alphas:
    model = Pipeline([
        ('scaler', StandardScaler()),
        ('lasso', Lasso(alpha=alpha, random_state=42, max_iter=10000))
    ])

    model.fit(X_train, y_train)

    train_scores.append(r2_score(y_train, model.predict(X_train)))
    test_scores.append(r2_score(y_test, model.predict(X_test)))

    coefs = model.named_steps['lasso'].coef_
    features_kept.append(np.sum(np.abs(coefs) > 1e-4))

    print(f"alpha={alpha}, Train R²={train_scores[-1]:.4f}, Test R²={test_scores[-1]:.4f}, Features kept={features_kept[-1]}")
# Out:
# alpha=0.0001, Train R²=0.6126, Test R²=0.5759, Features kept=8
# alpha=0.001, Train R²=0.6125, Test R²=0.5769, Features kept=8
# alpha=0.005, Train R²=0.6115, Test R²=0.5801, Features kept=7
# alpha=0.01, Train R²=0.6085, Test R²=0.5816, Features kept=7
# alpha=0.05, Train R²=0.5472, Test R²=0.5305, Features kept=4
# alpha=0.1, Train R²=0.4974, Test R²=0.4814, Features kept=3
# alpha=0.5, Train R²=0.2900, Test R²=0.2827, Features kept=1
# alpha=1.0, Train R²=0.0000, Test R²=-0.0002, Features kept=0

# %% [markdown]
# 2. Plot train and test R2 vs alpha, just like the Ridge plot above.

# %%
alphas = [0.0001, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1.0]

train_scores = []
test_scores = []

for alpha in alphas:
    pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('lasso', Lasso(alpha=alpha, random_state=42, max_iter=10000))
    ])

    pipe.fit(X_train, y_train)

    train_scores.append(r2_score(y_train, pipe.predict(X_train)))
    test_scores.append(r2_score(y_test, pipe.predict(X_test)))

# Plot
plt.figure(figsize=(8,5))
plt.semilogx(alphas, train_scores, 'o-', label='Train R²')
plt.semilogx(alphas, test_scores, 's-', label='Test R²')

plt.xlabel("Alpha (log scale)")
plt.ylabel("R² Score")
plt.title("Lasso Regression: Effect of Alpha")
plt.legend()
plt.grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# 3. For each alpha, count how many features Lasso keeps (coefficient ̸= 0). At what alpha does Lasso start removing features aggressively?

# %%
alphas = [0.0001, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1.0]

print("Lasso feature selection:\n")

for alpha in alphas:
    pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('lasso', Lasso(alpha=alpha, random_state=42, max_iter=10000))
    ])

    pipe.fit(X_train, y_train)

    coefs = pipe.named_steps['lasso'].coef_
    kept = np.sum(np.abs(coefs) > 1e-4)

    print(f"alpha = {alpha:<6}  features kept = {kept}")
# Out:
# Lasso feature selection:
#
# alpha = 0.0001  features kept = 8
# alpha = 0.001   features kept = 8
# alpha = 0.005   features kept = 7
# alpha = 0.01    features kept = 7
# alpha = 0.05    features kept = 4
# alpha = 0.1     features kept = 3
# alpha = 0.5     features kept = 1
# alpha = 1.0     features kept = 0

# %% [markdown]
# Lasso starts removing features aggressively at alpha = 0.05, where the number of features kept drops significantly from 7 to 4. This indicates that stronger regularization forces more coefficients to shrink to zero, causing the model to eliminate less important features.

# %% [markdown]
# 4. Which alpha gives the best test R2
# for Lasso?

# %%
best_idx = np.argmax(test_scores)
print(f"Best alpha: {alphas[best_idx]}")
print(f"Best test R^2: {test_scores[best_idx]:.4f}")
# Out:
# Best alpha: 0.01
# Best test R^2: 0.5816

# %% [markdown]
# #  Part 9: Final Model Comparison

# %% [markdown]
# ##  Step 1: Comprehensive Comparison

# %%
# Rebuild all models on the same split
X_train, X_test, y_train, y_test = train_test_split(
    X_all, y, test_size=0.2, random_state=42)

all_models = {
    "Simple LR(MedInc)": Pipeline([
        ("lr", LinearRegression())
    ]),
    "Multiple LR(all)": Pipeline([
        ("scaler", StandardScaler()),
        ("lr", LinearRegression())
    ]),
    "Polynomial(deg=2)": Pipeline([
        ("scaler", StandardScaler()),
        ("poly", PolynomialFeatures(degree=2,
                                    include_bias=False)),
        ("lr", LinearRegression())
    ]),
    "Ridge": Pipeline([
        ("scaler", StandardScaler()),
        ("model", Ridge(alpha=1.0))
    ]),
    "Lasso": Pipeline([
        ("scaler", StandardScaler()),
        ("model", Lasso(alpha=0.01))
    ]),
    "ElasticNet": Pipeline([
        ("scaler", StandardScaler()),
        ("model", ElasticNet(alpha=0.01, l1_ratio=0.5))
    ]),
}

# Evaluate
print(f"{"Model":<25} {"RMSE":>8} {"MAE":>8}"
      f"{"R^2":>8} {"# Features":>10}")
print("=" * 67)

comparison_data = []
for name, pipe in all_models.items():
    # Simple LR uses only MedInc
    if "Simple" in name:
      X_tr = X_train[:, [0]] # MedInc column
      X_te = X_test[:, [0]]
    else:
      X_tr, X_te = X_train, X_test

    pipe.fit(X_tr, y_train)
    y_pred = pipe.predict(X_te)

    rmse_v = np.sqrt(mean_squared_error(y_test, y_pred))
    mae_v = mean_absolute_error(y_test, y_pred)
    r2_v = r2_score(y_test, y_pred)

    # Count effective features
    if "poly" in pipe.named_steps:
        n_feat = pipe.named_steps["poly"].n_output_features_
    elif "Simple" in name:
        n_feat = 1
    else:
        n_feat = X_train.shape[1]

    comparison_data.append({
        "Model": name, "RMSE": rmse_v,
        "MAE": mae_v, "R2": r2_v, "Features": n_feat})

    print(f"{name:<25} {rmse_v:>8.4f} {mae_v:>8.4f} {r2_v:>8.4f} {n_feat:>10}")
# Out:
# Model                         RMSE      MAE     R^2 # Features
# ...
# Simple LR(MedInc)           0.8421   0.6299   0.4589          1
# Multiple LR(all)            0.7456   0.5332   0.5758          8
# Polynomial(deg=2)           0.6814   0.4670   0.6457         44
# Ridge                       0.7456   0.5332   0.5758          8
# Lasso                       0.7404   0.5353   0.5816          8
# ElasticNet                  0.7416   0.5341   0.5803          8

# %% [markdown]
# ## Step 2: Visual Comparison

# %%
comp_df = pd.DataFrame(comparison_data)
fig, axes = plt.subplots(1, 2, figsize =(14, 5))

# R^2 comparison
axes[0].barh(comp_df["Model"], comp_df["R2"], color="steelblue")
axes[0].set_xlabel("R^2 Score")
axes[0].set_title("Model Comparison: R^2(higher is better)")
axes[0].set_xlim (0, 1)

# RMSE comparison
axes[1].barh(comp_df["Model"], comp_df["RMSE"], color="coral")
axes[1].set_xlabel("RMSE")
axes[1].set_title("Model Comparison: RMSE(lower is better)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 8: Draw Conclusions

# %% [markdown]
# 1. Which model achieved the best R2 on the test set? Which had the lowest RMSE?

# %% [markdown]
# The Polynomial Regression (degree 2) model achieved the best R² score (0.6457) on the test set and also had the lowest RMSE (0.6814). This indicates that it provides the most accurate predictions among all the models tested, as it explains more variance in the data while producing smaller prediction errors.

# %% [markdown]
# 2. The Polynomial (degree 2) model uses 44 features. Is the improvement in R2 worth the added complexity? Justify your answer.

# %% [markdown]
# Yes, the improvement in R² is worth the added complexity. The Polynomial (degree 2) model increases the R² score from about 0.58 to 0.65 and reduces the RMSE from about 0.74 to 0.68, indicating more accurate predictions. Although the model uses 44 features instead of 8, the performance improvement is meaningful because polynomial features help capture nonlinear relationships in the data that linear models cannot represent.

# %% [markdown]
# 3. If you had to deploy one model in production for a real estate company, which would you choose and why? Consider accuracy, interpretability, and simplicity.

# %% [markdown]
# Although the Polynomial (degree 2) model has the highest accuracy, it uses 44 features, making it more complex and harder to interpret. Lasso Regression provides good accuracy (R² ≈ 0.58) while using only the original 8 features. It also performs feature selection by removing less important predictors, which makes the model simpler and easier to explain. Therefore, Lasso Regression offers a better balance between accuracy, interpretability, and simplicity, making it a good choice for deployment in a real estate company.

# %% [markdown]
# 4. Why do Ridge, Lasso, and ElasticNet perform similarly to standard Linear Regression on this dataset?

# %% [markdown]
# Ridge, Lasso, and ElasticNet perform similarly to standard Linear Regression because the dataset has only a small number of features (8) and does not suffer from strong overfitting. Since Linear Regression already generalizes well on this dataset, adding regularization only slightly adjusts the coefficients. As a result, the overall prediction performance remains very similar across these models.

# %% [markdown]
# # Part 10: Apply to a New Dataset – Saudi Housing

# %% [markdown]
# ## Step 1: Create the Saudi Housing Dataset

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
n = 500

cities = np.random.choice(
    ["Jeddah", "Riyadh", "Dammam", "Makkah", "Madinah"],
    n, p=[0.30, 0.30, 0.15, 0.15, 0.10])

# Base price varies by city(in SAR thousands)
city_base = {"Jeddah": 850, "Riyadh": 900, "Dammam": 650,
             "Makkah": 1100, "Madinah": 750}
base = np.array([ city_base[c] for c in cities], dtype=float)

area = np.round(np.random.uniform(80, 400, n), 1)
bedrooms = np.random.randint(1, 7, n)
bathrooms = np.random.randint(1, 5, n)
age = np.random.randint(0, 40, n)
floor = np.random.randint(1, 15, n)
has_parking = np.random.choice([0, 1], n, p=[0.3, 0.7])

# Generate price with realistic relationships
price = (base
         + 3.5 * area
         + 80 * bedrooms
         + 50 * bathrooms
         - 12 * age
         + 15 * floor
         + 100 * has_parking
         + np.random.normal(0, 150, n)) # noise
price = np.round(np.maximum(price, 200), 1)

df_saudi = pd.DataFrame({
    "city": cities,
    "area_sqm": area,
    "bedrooms": bedrooms,
    "bathrooms": bathrooms,
    "age_years": age,
    "floor": floor,
    "has_parking": has_parking,
    "price_kSAR": price # price in thousands of SAR
})

df_saudi.to_csv("saudi_housing.csv", index=False)
print(f"Dataset shape: {df_saudi.shape}")
print(df_saudi.head(10))
print(f"\nPrice statistics(thousands SAR):")
print(df_saudi["price_kSAR"].describe().round(1))
# Out:
# Dataset shape: (500, 8)
#       city  area_sqm  bedrooms  bathrooms  age_years  floor  has_parking  \
# 0   Riyadh     303.4         4          4         24     11            0
# 1  Madinah     251.6         6          4          1      1            1
# 2   Dammam     179.0         3          1         34     14            0
# 3   Riyadh     340.4         5          3          6     14            1
# 4   Jeddah     299.1         1          3         20      6            0
# 5   Jeddah     132.0         5          4         17     13            1
# 6   Jeddah     371.5         6          2          2      6            0
# 7   Makkah     343.2         6          3         38      1            1
# 8   Dammam     383.9         1          3         10     11            1
# 9   Dammam     312.2         2          1         38     13            0
#
#    price_kSAR
# 0      2527.3
# 1      2491.2
# 2      1345.8
# 3      2941.9
# 4      2022.0
# 5      2264.8
# 6      2821.1
# 7      2532.7
# ...

# %% [markdown]
# ### Task 9: Full Saudi Housing Analysis (Challenge)
# Apply everything you learned in this lab to the saudi housing.csv dataset:

# %% [markdown]
# 1. Explore: Use df.describe(), df.corr(), and scatter plots to understand the data. Which feature correlates most with price?

# %%
print("Statistical Summary:")
print(df_saudi.describe().round(2))

print("\nCorrelation with price_kSAR:")
print(df_saudi.corr(numeric_only=True)['price_kSAR'].sort_values(ascending=False))

# Scatter plots for numeric features
features = ['area_sqm', 'bedrooms', 'bathrooms', 'age_years', 'floor']

plt.figure(figsize=(15,4))

for i, feat in enumerate(features, 1):
    plt.subplot(1,5,i)
    plt.scatter(df_saudi[feat], df_saudi['price_kSAR'], alpha=0.6)
    plt.xlabel(feat)
    plt.ylabel('price_kSAR')
    plt.title(f'{feat} vs Price')

plt.tight_layout()
plt.show()

# Parking vs Price
plt.figure(figsize=(5,4))
plt.scatter(df_saudi['has_parking'], df_saudi['price_kSAR'], alpha=0.6)
plt.xlabel('has_parking')
plt.ylabel('price_kSAR')
plt.title('Parking vs Price')
plt.show()

# Check correlations with price
corr = df_saudi.corr(numeric_only=True)['price_kSAR'].sort_values(ascending=False)
print("\nFeature correlations with price_kSAR:")
print(corr)
# Out:
# Statistical Summary:
#        area_sqm  bedrooms  bathrooms  age_years   floor  has_parking  \
# count    500.00    500.00     500.00      500.0  500.00       500.00
# mean     234.22      3.50       2.45       19.6    7.52         0.71
# std       91.36      1.71       1.13       11.6    3.97         0.46
# min       81.50      1.00       1.00        0.0    1.00         0.00
# 25%      153.35      2.00       1.00       10.0    4.00         0.00
# 50%      231.00      3.00       2.00       20.0    8.00         1.00
# 75%      312.40      5.00       3.00       30.0   11.00         1.00
# max      399.90      6.00       4.00       39.0   14.00         1.00
#
#        price_kSAR
# count      500.00
# mean      2044.35
# std        452.24
# min        833.80
# 25%       1737.22
# 50%       2038.55
# 75%       2344.07
# max       3326.90
#
# Correlation with price_kSAR:
# price_kSAR     1.000000
# area_sqm       0.730056
# bedrooms       0.300025
# bathrooms      0.090535
# ...

# %% [markdown]
# The feature that correlates most strongly with price_kSAR is area_sqm, with a correlation of approximately 0.73. This indicates that larger houses tend to have higher prices. The scatter plot between area_sqm and price_kSAR also shows a clear positive relationship, confirming that house size is the strongest predictor of price in this dataset.

# %% [markdown]
# 2. Preprocess: Encode the city column using One-Hot encoding (from Lab 3). Scale the numeric features.

# %%
# Separate features and target
X = df_saudi.drop('price_kSAR', axis=1)
y = df_saudi['price_kSAR']

from sklearn.preprocessing import OneHotEncoder, StandardScaler

# One-Hot encode the city column
city_encoded = pd.get_dummies(X['city'], prefix='city')

# Remove original city column
X_numeric = X.drop('city', axis=1)

# Combine encoded city with numeric features
X_processed = pd.concat([X_numeric, city_encoded], axis=1)

print("Processed features shape:", X_processed.shape)

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_processed)

# Convert back to DataFrame
X_scaled = pd.DataFrame(X_scaled, columns=X_processed.columns)

print("Scaled features shape:", X_scaled.shape)
X_scaled.head()
# Out:
# Processed features shape: (500, 11)
# Scaled features shape: (500, 11)
#    area_sqm  bedrooms  bathrooms  age_years     floor  has_parking  \
# 0  0.757936  0.290737   1.376475   0.379785  0.876833    -1.557131
# 1  0.190376  1.458353   1.376475  -1.605454 -1.644250     0.642207
# 2 -0.605085 -0.293072  -1.284237   1.242932  1.633157    -1.557131
# 3  1.163336  0.874545   0.489571  -1.173880  1.633157     0.642207
# 4  0.710822 -1.460688   0.489571   0.034526 -0.383709    -1.557131
#
#    city_Dammam  city_Jeddah  city_Madinah  city_Makkah  city_Riyadh
# 0    -0.423374    -0.667148     -0.351562    -0.423374     1.611559
# 1    -0.423374    -0.667148      2.844452    -0.423374    -0.620517
# 2     2.361980    -0.667148     -0.351562    -0.423374    -0.620517
# 3    -0.423374    -0.667148     -0.351562    -0.423374     1.611559
# 4    -0.423374     1.498917     -0.351562    -0.423374    -0.620517

# %% [markdown]
# 3. Simple model: Train a Linear Regression using only area sqm. Plot the regression line and report R2.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Use only area_sqm as the feature
X_simple = df_saudi[['area_sqm']]
y = df_saudi['price_kSAR']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(
    X_simple, y, test_size=0.2, random_state=42
)

# Train Linear Regression model
model_simple = LinearRegression()
model_simple.fit(X_train, y_train)

# Predict
y_pred = model_simple.predict(X_test)

# Calculate R²
r2 = r2_score(y_test, y_pred)
print(f"R² score: {r2:.4f}")

# Plot regression line
plt.figure(figsize=(8,5))
plt.scatter(X_test['area_sqm'], y_test, alpha=0.6, label="Actual")

x_line = pd.DataFrame({
    'area_sqm': np.linspace(X_test['area_sqm'].min(), X_test['area_sqm'].max(), 100)
})

y_line = model_simple.predict(x_line)

plt.plot(x_line, y_line, color='red', linewidth=2, label="Regression Line")

plt.xlabel("Area (sqm)")
plt.ylabel("Price (kSAR)")
plt.title("Simple Linear Regression: Area vs Price")

plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# R² score: 0.4932

# %% [markdown]
# The simple linear regression model using only area_sqm achieved an R² score of about 0.54. This indicates that house area alone explains a significant portion of the variation in house prices. The regression line in the plot shows a clear positive relationship between area_sqm and price_kSAR, meaning larger houses generally have higher prices.

# %% [markdown]
# 4. Multiple model: Train with all features. How much does R2 improve?

# %%
# Use already processed data
X_all = X_scaled
y_all = y

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_all, y_all, test_size=0.2, random_state=42
)

# Train model
model_all = LinearRegression()
model_all.fit(X_train, y_train)

# Predict
y_pred_all = model_all.predict(X_test)

# Calculate R^2
r2_all = r2_score(y_test, y_pred_all)

print(f"R^2 score (all features): {r2_all:.4f}")
# Out:
# R^2 score (all features): 0.8645

# %% [markdown]
# The R² score improved from 0.4932 in the simple model to 0.8645 when using all features. This is an improvement of 0.3713 (37.13 percentage points). The large increase shows that including additional variables such as bedrooms, bathrooms, age, floor, parking, and city provides much more information for predicting house prices, significantly improving the model’s accuracy.

# %% [markdown]
# 5. Regularized models: Train Ridge, Lasso, and ElasticNet. Compare their performance.

# %%
# Define the models with preprocessing (scaling)
models = {
    "Ridge (alpha=1.0)": Pipeline([
        ("scaler", StandardScaler()),
        ("model", Ridge(alpha=1.0))
    ]),
    "Lasso (alpha=0.01)": Pipeline([
        ("scaler", StandardScaler()),
        ("model", Lasso(alpha=0.01, max_iter=20000))
    ]),
    "ElasticNet (alpha=0.01)": Pipeline([
        ("scaler", StandardScaler()),
        ("model", ElasticNet(alpha=0.01, l1_ratio=0.5, max_iter=20000))
    ]),
}

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train and evaluate each model
for name, pipe in models.items():
    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))

    print(f"{name:<20} R^2: {r2:.4f}  RMSE: {rmse:.2f}")
# Out:
# Ridge (alpha=1.0)    R^2: 0.8643  RMSE: 173.14
# Lasso (alpha=0.01)   R^2: 0.8645  RMSE: 173.03
# ElasticNet (alpha=0.01) R^2: 0.8642  RMSE: 173.26

# %% [markdown]
# The Ridge, Lasso, and ElasticNet models all perform very similarly, each achieving an R² of about 0.86 and a low RMSE, meaning they explain around 86% of the variance in house prices. Among them, Lasso (alpha = 0.01) slightly outperforms the others with the highest R² and lowest RMSE. In addition, Lasso has the advantage of feature selection, as it can shrink less important coefficients to zero, making the model simpler while maintaining strong predictive performance.

# %% [markdown]
# 6. Feature importance: Which features does Lasso consider most important? Does this match your intuition about Saudi housing prices?

# %%
# Get trained Lasso model from pipeline
lasso_model = models["Lasso (alpha=0.01)"].named_steps["model"]

# Get coefficients
coeffs = lasso_model.coef_

# Match coefficients with feature names
feature_names = X_scaled.columns

importance = pd.DataFrame({
    "Feature": feature_names,
    "Coefficient": coeffs,
    "Importance": abs(coeffs)
}).sort_values("Importance", ascending=False)

print(importance)
# Out:
#          Feature  Coefficient  Importance
# 0       area_sqm   333.999492  333.999492
# 1       bedrooms   142.302433  142.302433
# 3      age_years  -128.050350  128.050350
# 6    city_Dammam   -93.456198   93.456198
# 9    city_Makkah    88.854859   88.854859
# 4          floor    74.013643   74.013643
# 2      bathrooms    53.945294   53.945294
# 8   city_Madinah   -47.080976   47.080976
# 5    has_parking    42.224885   42.224885
# 7    city_Jeddah   -24.116494   24.116494
# 10   city_Riyadh     0.001161    0.001161

# %% [markdown]
# Lasso identified area_sqm, bedrooms, and age_years as the most important features based on the magnitude of their coefficients. Larger houses and homes with more bedrooms tend to have higher prices, while older houses generally have lower prices. This matches intuition about Saudi housing prices, where property size and number of rooms strongly influence value, and newer homes are usually more desirable.

# %% [markdown]
# 7. Comparison table: Create a summary table comparing all models (RMSE, MAE, R2 ) and identify the best model.

# %%
# Create comparison table for all models
results = []

for name, pipe in models.items():

    # Train model
    pipe.fit(X_train, y_train)

    # Predict
    y_pred = pipe.predict(X_test)

    # Calculate metrics
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Store results
    results.append([name, rmse, mae, r2])

# Create DataFrame
comparison_table = pd.DataFrame(
    results,
    columns=["Model", "RMSE", "MAE", "R²"]
).sort_values("R²", ascending=False)

print(comparison_table)

# Identify best model
print("\nBest model:", comparison_table.iloc[0]["Model"])
# Out:
#                      Model        RMSE         MAE        R²
# 1       Lasso (alpha=0.01)  173.033289  137.306731  0.864511
# 0        Ridge (alpha=1.0)  173.141951  137.376746  0.864341
# 2  ElasticNet (alpha=0.01)  173.263216  137.454921  0.864151
#
# Best model: Lasso (alpha=0.01)

# %% [markdown]
# The comparison table shows that Lasso (alpha = 0.01) achieved the best performance, with the highest R² and lowest error values among the tested models. This indicates that Lasso provides the most accurate predictions while also performing feature selection, making it a strong choice for this dataset.

# %% [markdown]
# # Lab Report

# %% [markdown]
# A short report (5–7 sentences) comparing the regression models you trained. Include: which model performed best, what role regularization played, and which features were
# most predictive of house prices.

# %% [markdown]
# The regression models showed clear differences in performance and predictive ability.
# The simple linear regression model using only area_sqm provided a basic prediction but had limited accuracy because it relied on a single feature.
# The multiple linear regression model using all features significantly improved performance, achieving a much higher R² and lower prediction error.
# Regularization methods such as Ridge, Lasso, and ElasticNet produced very similar results to standard linear regression because the dataset has a small number of features and does not suffer from strong overfitting.
# Among the regularized models, Lasso was particularly useful because it performed feature selection by removing less important features.
# The most predictive features for Saudi housing prices were area_sqm, bedrooms, and age_years, which aligns with intuition since larger houses with more rooms generally have higher prices while older properties tend to decrease in value.
